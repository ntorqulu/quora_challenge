# %% [markdown]
# # Utils Helper Function Explanations
# Document and explain all functions in `utils.py`.
# The features are grouped into three categories: statistical, NLP and Graph.

# %% [markdown]
# ## Statistical Features
#
# ### `jaccard_similarity(text1, text2, remove_stopwords=False)`
#
# $$\text{Jaccard}(A, B) = \frac{|A \cap B|}{|A \cup B|}$$
